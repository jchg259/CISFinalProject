# %%
from input import SequenceInput, ScoringMatrixChoice, GlobalAlignment, OtherMatrix, SecondGlobalAlignment

# %% [markdown]
# You are going to be able to see alignments through various scoring matrices. Enjoy!

# %%
s1, s2 = SequenceInput()

# %%
Best, Num = ScoringMatrixChoice(s1, s2)
print(Best)
print(Num)
# Out:
# Here is a list of the Scores: [ 72.   7.  37.  69.  54.  25.  27.  46.  69.  59.  -2.  62.  57.  55.
#   79. -19.  30.  30. -28.  65.  77.  64.  57.  77.  51.  62.  34. -69.
#   69.  65.  58.  69.  40.  62.  51.  72.  40.  28.  76.  65.  58.  51.
#   55.  64.  51.  63.  64.  71.  17.  38.]
# The best score is:  -69.0 and comes from the scoring matrix PAM 280
# 280
# 1

# %%
GlobalAlignment(s1, s2, Best, Num)

# %%
Best_Two, Num_Two = OtherMatrix(s1, s2, Num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Best_Two, Num_Two = OtherMatrix(s1, s2, Num)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
SecondGlobalAlignment(s1, s2, Best_Two, Num_Two)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 SecondGlobalAlignment(s1, s2, Best_Two, Num_Two)
#
# File ~/Documents/CIS Final Project/CISFinalProject/input.py:86, in SecondGlobalAlignment(sequence1, sequence2, Best, num)
#      83         print("Great! Thanks for using this program.")
#      84         return 0, 5
# ---> 86 def SecondGlobalAlignment(sequence1, sequence2, Best, num):
#      87     if num == 5:
#      88         exit
#
# NameError: name 'exit' is not defined
